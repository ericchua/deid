# %%
# Batch convert DICOM to PNG
# Copied from convert_image.py

import mritopng
# import os

dicom_path = 'D:\deid\Images\DICOM'
png_path = 'D:\deid\Images\PNG'

# def convertImg(dicomImage):
#     print("Image: " + dicomImage)
#     outputImg = dicomImage.split('.')
#     mritopng.convert_file(os.path.join(dicom_path, dicomImage), os.path.join(dicom_path, outputImg[0] + '.jpg'), auto_contrast=True)

#     convertedImg = os.path.join(dicom_path, outputImg[0] + '.jpg')
#     return convertedImg

mritopng.convert_folder(dicom_path, png_path)

# def rename(): 
#     i = 0

#     for filename in os.listdir(dicom_path): 
#         dst =str(i) + ".png"
#         src =png_path + filename + ".png"
#         dst =png_path + dst 
          
#         # rename() function will 
#         # rename all the files 
#         os.rename(src, dst) 
#         i += 1

# rename()
# Out:
# SUCCESS: D:\deid\Images\DICOM\Anonymized_20210725\series-00000\image-00000.dcm --> D:\deid\Images\PNG\Anonymized_20210725\series-00000\image-00000.dcm.png
# SUCCESS: D:\deid\Images\DICOM\Anonymized_20210725\series-00000\image-00001.dcm --> D:\deid\Images\PNG\Anonymized_20210725\series-00000\image-00001.dcm.png
# SUCCESS: D:\deid\Images\DICOM\Anonymized_20210725\series-00000\image-00002.dcm --> D:\deid\Images\PNG\Anonymized_20210725\series-00000\image-00002.dcm.png
# SUCCESS: D:\deid\Images\DICOM\Anonymized_20210725\series-00000\image-00003.dcm --> D:\deid\Images\PNG\Anonymized_20210725\series-00000\image-00003.dcm.png
# SUCCESS: D:\deid\Images\DICOM\Anonymized_20210725\series-00000\image-00004.dcm --> D:\deid\Images\PNG\Anonymized_20210725\series-00000\image-00004.dcm.png
# SUCCESS: D:\deid\Images\DICOM\Anonymized_20210725\series-00000\image-00005.dcm --> D:\deid\Images\PNG\Anonymized_20210725\series-00000\image-00005.dcm.png
# ...
